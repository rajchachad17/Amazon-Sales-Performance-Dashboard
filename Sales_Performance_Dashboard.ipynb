# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('amazon (raw_data).csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# Selecting Required Columns

# %%
df = df[
     [
        "product_id",
        "product_name",
        "category",
        "discounted_price",
        "actual_price",
        "discount_percentage",
        "rating",
        "rating_count",
        "user_id",
        "review_id"
    ]
]

# %%
df.columns.values
# Out:
# array(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'user_id', 'review_id'], dtype=object)

# %%
#col_names = ['Product_id', 'Product_name', 'Category', 'Discounted_price', 'Actual_price', 'Discount_percentage', 'Rating', 'Rating_count', 'User_id', 'Review_id']

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# Clean "Discounted Price", "Actual Price" Column

# %%
df.columns.values
# Out:
# array(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'user_id', 'review_id'], dtype=object)

# %%
df["discounted_price"] = (
    df["discounted_price"]
    .str.replace("₹", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

df['discounted_price'][0:4]
# Out:
# 0    399.0
# 1    199.0
# 2    199.0
# 3    329.0
# Name: discounted_price, dtype: float64

# %%
df["actual_price"] = (
    df["actual_price"]
    .str.replace("₹", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

df['actual_price'][0:4]
# Out:
# 0    1099.0
# 1     349.0
# 2    1899.0
# 3     699.0
# Name: actual_price, dtype: float64

# %%
df["discount_percentage"] = (
    df["discount_percentage"]
    .str.replace("%", "", regex=False)
    .astype(float)
)
df["discount_percentage"][0:4]
# Out:
# 0    64.0
# 1    43.0
# 2    90.0
# 3    53.0
# Name: discount_percentage, dtype: float64

# %% [markdown]
# Classify Rating into categories & working with rating count

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df['rating_count'] = df['rating_count'].str.replace(',', '', regex=True)
df['rating_count']
# Out:
# 0       24269
# 1       43994
# 2        7928
# 3       94363
# 4       16905
#         ...
# 1460     1090
# 1461     4118
# 1462      468
# 1463     8031
# 1464     6987
# Name: rating_count, Length: 1465, dtype: object

# %% [markdown]
# Handling Missing Values

# %%
# Drop rows if core identity or pricing columns are missing
df = df.dropna(
    subset=[
        "product_id",
        "product_name",
        "discounted_price",
        "actual_price"
    ]
)

# %% [markdown]
# HANDLE ISSING VALUES

# %% [markdown]
# MISTAKE TO AVOID

# %%
#df['category'] = df.fillna('UNKNOWN_CATEGORY', inplace=True)

#df['discount_percentage'] = (df['actual_price']-df['discounted_price'])/df['actual_price']*100

#df["rating"] = df.groupby("category")["rating"].transform(lambda x: x.fillna(x.mean()))

#df['rating_count'] = df.fillna(0, inplace=True)

#df['user_id'] = df.fillna('UNKNOWN_USER', inplace=True)

#df['review_id'] = df.fillna(0, inplace=True)

# %% [markdown]
# THE SOLUTION

# %%
df['category'] = df['category'].fillna('UNKNOWN_CATEGORY')

df['discount_percentage'] = (
    (df['actual_price'] - df['discounted_price']) / df['actual_price'] * 100
)

df['rating'] = df.groupby('category')['rating']\
                 .transform(lambda x: x.fillna(x.mean()))

df['rating_count'] = df['rating_count'].fillna(0)

df['user_id'] = df['user_id'].fillna('UNKNOWN_USER')

df['review_id'] = df['review_id'].fillna(0)

# %%
df.columns.values
# Out:
# array(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'user_id', 'review_id'], dtype=object)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0            63.694268     4.2        24269
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# user_id                0
# review_id              0
# dtype: int64

# %% [markdown]
# # Clean Data Checkpoint

# %%
clean_df = df.copy()
clean_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating rating_count  \
# 0        1099.0            63.694268     4.2        24269
# ...

# %%
clean_df.to_excel("clean_amazon_df.xlsx",index=False)

# %%
clean_df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
clean_df.shape
# Out:
# (1465, 10)

# %%
clean_df.columns.values
# Out:
# array(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'user_id', 'review_id'], dtype=object)

# %% [markdown]
# # SQL CHECKPOINT

# %%
import sqlite3

# Create SQLite database file
conn = sqlite3.connect("amazon_analysis.db")

# Load dataframe into SQLite
clean_df.to_sql(
    name="amazon_products",
    con=conn,
    if_exists="replace",
    index=False
)

print("Data loaded into SQLite successfully")
# Out:
# Data loaded into SQLite successfully

# %%
pd.read_sql("SELECT COUNT(*) FROM amazon_products", conn)
# Out:
#    COUNT(*)
# 0      1465

# %% [markdown]
# View Data

# %%
pd.read_sql(
    "SELECT * FROM amazon_products LIMIT 6",
    conn
)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
# 5  Computers&Accessories|Accessories&Peripherals|...             149.0
#
# ...

# %% [markdown]
# Products per Category

# %%
pd.read_sql(
    """
    SELECT category, COUNT(*) AS product_count
    FROM amazon_products
    GROUP BY category
    ORDER BY product_count DESC
    """,
    conn
)
# Out:
#                                               category  product_count
# 0    Computers&Accessories|Accessories&Peripherals|...            233
# 1          Electronics|WearableTechnology|SmartWatches             76
# 2    Electronics|Mobiles&Accessories|Smartphones&Ba...             68
# 3    Electronics|HomeTheater,TV&Video|Televisions|S...             63
# 4    Electronics|Headphones,Earbuds&Accessories|Hea...             52
# ..                                                 ...            ...
# 206  Computers&Accessories|Accessories&Peripherals|...              1
# 207  Computers&Accessories|Accessories&Peripherals|...              1
# 208  Computers&Accessories|Accessories&Peripherals|...              1
# 209  Computers&Accessories|Accessories&Peripherals|...              1
# 210  Car&Motorbike|CarAccessories|InteriorAccessori...              1
#
# [211 rows x 2 columns]

# %% [markdown]
# Average Rating by Category

# %%
pd.read_sql(
    """
    SELECT category, ROUND(AVG(rating), 2) AS avg_rating
    FROM amazon_products
    GROUP BY category
    ORDER BY avg_rating DESC
    """,
    conn
)
# Out:
#                                               category  avg_rating
# 0                        Computers&Accessories|Tablets         4.6
# 1    OfficeProducts|OfficeElectronics|Calculators|B...         4.5
# 2            HomeImprovement|Electrical|CordManagement         4.5
# 3    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...         4.5
# 4    Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea...         4.5
# ..                                                 ...         ...
# 206  Computers&Accessories|Accessories&Peripherals|...         3.6
# 207  Electronics|HomeTheater,TV&Video|Accessories|3...         3.5
# 208  Computers&Accessories|Accessories&Peripherals|...         3.5
# 209  Computers&Accessories|Accessories&Peripherals|...         3.4
# 210  Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea...         3.3
#
# [211 rows x 2 columns]

# %% [markdown]
# Top 10 highest-rated products

# %%
pd.read_sql(
    """
    SELECT product_name, rating
    FROM amazon_products
    ORDER BY rating DESC
    LIMIT 10
    """,
    conn
)
# Out:
#                                         product_name  rating
# 0  Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 1  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0
# 2  Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 3  Swiffer Instant Electric Water Heater Faucet T...     4.8
# 4  Oratech Coffee Frother electric, milk frother ...     4.8
# 5  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8
# 6  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...     4.7
# 7  Spigen EZ Fit Tempered Glass Screen Protector ...     4.7
# 8  FIGMENT Handheld Milk Frother Rechargeable, 3-...     4.7
# 9  Zuvexa USB Rechargeable Electric Foam Maker - ...     4.7

# %%
clean_df.columns.values
# Out:
# array(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'user_id', 'review_id'], dtype=object)

# %% [markdown]
# Products with high discount but low rating

# %%
pd.read_sql(
    """
    SELECT product_name, discounted_price, actual_price, discount_percentage
    FROM amazon_products
    WHERE discount_percentage > 40
    ORDER BY discount_percentage DESC
    LIMIT 10
    """,
    conn
)
# Out:
#                                         product_name  discounted_price  \
# 0  rts [2 Pack] Mini USB C Type C Adapter Plug, T...             294.0
# 1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            1799.0
# 2  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            1799.0
# 3  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            1799.0
# 4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            1799.0
# 5  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...            1799.0
# 6  Sounce Spiral Charger Cable Protector Data Cab...              99.0
# 7  LAPSTER 12pcs Spiral Cable Protectors for Char...              99.0
# 8  LAPSTER Spiral Charger Spiral Charger Cable Pr...              99.0
# 9  Sounce Spiral Charger Cable Protector Data Cab...              99.0
#
#    actual_price  discount_percentage
# 0        4999.0            94.118824
# 1       19999.0            91.004550
# 2       19999.0            91.004550
# ...

# %% [markdown]
# Best Price Segment

# %%
pd.read_sql(
    """
    SELECT
        CASE
            WHEN discounted_price < 500 THEN 'Low'
            WHEN discounted_price BETWEEN 500 AND 2000 THEN 'Medium'
            ELSE 'High'
        END AS price_range,
        ROUND(AVG(rating), 2) AS avg_rating,
        COUNT(product_id) AS total_products
    FROM amazon_products
    GROUP BY price_range
    ORDER BY avg_rating DESC;
    """,
    conn
)
# Out:
#   price_range  avg_rating  total_products
# 0        High        4.14             362
# 1      Medium        4.09             527
# 2         Low        4.07             576

# %%
pd.read_sql(
    """
    SELECT
        category,
        ROUND(AVG(rating), 2) AS avg_rating,
        COUNT(product_id) AS total_products
    FROM amazon_products
    GROUP BY category
    HAVING avg_rating >= 4.2
    ORDER BY total_products DESC;
    """,
    conn
)
# Out:
#                                              category  avg_rating  \
# 0   Electronics|HomeTheater,TV&Video|Televisions|S...        4.21
# 1   Electronics|HomeTheater,TV&Video|Accessories|C...        4.25
# 2   Computers&Accessories|Accessories&Peripherals|...        4.29
# 3         Electronics|Accessories|MemoryCards|MicroSD        4.33
# 4   Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...        4.29
# ..                                                ...         ...
# 87  Computers&Accessories|ExternalDevices&DataStor...        4.30
# 88            Computers&Accessories|Components|Memory        4.50
# 89  Computers&Accessories|Components|InternalHardD...        4.20
# 90  Computers&Accessories|Accessories&Peripherals|...        4.30
# 91  Computers&Accessories|Accessories&Peripherals|...        4.40
#
#     total_products
# 0               63
# 1               24
# 2               24
# 3               13
# 4               11
# ..             ...
# 87               1
# ...

# %% [markdown]
# Rating Distribution

# %%
pd.read_sql(
    """
    SELECT
        CASE
            WHEN rating >= 4.5 THEN 'Excellent'
            WHEN rating BETWEEN 4.0 AND 4.49 THEN 'Good'
            WHEN rating BETWEEN 3.0 AND 3.99 THEN 'Average'
            ELSE 'Poor'
        END AS rating_category,
        COUNT(product_id) AS product_count
    FROM amazon_products
    GROUP BY rating_category
    ORDER BY product_count DESC;
    """,
    conn
)
# Out:
#   rating_category  product_count
# 0            Good           1006
# 1         Average            349
# 2       Excellent            104
# 3            Poor              6

# %% [markdown]
# Most Popular High-Rated Products

# %%
pd.read_sql(
    """
    SELECT
        product_name,
        category,
        rating,
        rating_count,
        discount_percentage
    FROM amazon_products
    WHERE rating >= 4.5
    ORDER BY rating_count DESC
    LIMIT 5;
    """,
    conn
)
# Out:
#                                         product_name  \
# 0  Camel Oil Pastel with Reusable Plastic Box - 5...
# 1  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...
# 2  Melbon VM-905 2000-Watt Room Heater (ISI Certi...
# 3  Cuzor 12V Mini ups for WiFi Router | Power Bac...
# 4  Classmate Soft Cover 6 Subject Spiral Binding ...
#
#                                             category  rating rating_count  \
# 0      Home&Kitchen|CraftMaterials|PaintingMaterials     4.5         9427
# 1  Computers&Accessories|Components|InternalSolid...     4.5        92925
# 2  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...     4.6            9
# 3    Computers&Accessories|NetworkingDevices|Routers     4.5         8656
# 4  OfficeProducts|OfficePaperProducts|Paper|Stati...     4.5         8618
#
#    discount_percentage
# 0             0.000000
# 1            41.451613
# 2            66.722241
# 3            50.016672
# 4             1.875000

# %% [markdown]
# Price Sensitivity Analysis

# %%
pd.read_sql(
    """
    SELECT
        CASE
            WHEN discounted_price < 500 THEN 'Low'
            WHEN discounted_price BETWEEN 500 AND 2000 THEN 'Medium'
            ELSE 'High'
        END AS price_range,
        ROUND(AVG(discounted_price), 2) AS avg_price,
        ROUND(AVG(rating), 2) AS avg_rating
    FROM amazon_products
    GROUP BY price_range
    ORDER BY avg_price;
    """,
    conn
)
# Out:
#   price_range  avg_price  avg_rating
# 0         Low     276.73        4.07
# 1      Medium    1140.05        4.09
# 2        High   10548.00        4.14

# %%
conn.close()
